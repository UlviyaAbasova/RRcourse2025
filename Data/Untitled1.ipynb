# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('onet_tasks.csv')  # Replace with your actual filename
df.head()
# Out:
#    isco08   t_1A1f1   t_1A2a2    t_2B1a   t_4A2a4   t_4A2b2   t_4A3a3  \
# 0    1112  1.561667  1.373333  3.916667  3.898333  3.806667  1.970000
# 1    1113  1.185000  1.000000  4.000000  4.105000  4.180000  1.380000
# 2    1114  1.416667  1.510000  3.750000  3.848333  3.457500  2.370833
# 3    1120  1.342500  1.250000  4.000000  3.907500  3.750000  2.035000
# 4    1211  1.000000  1.166667  3.290000  4.400000  3.603333  1.400000
#
#     t_4A3a4   t_4A4a1   t_4A4a4  ...   t_4C3b7   t_4C3d3  t_4C3b8_rev  \
# 0  2.206667  3.931667  4.376667  ...  3.028333  1.370000     1.443333
# 1  1.420000  4.075000  4.390000  ...  2.735000  1.390000     1.330000
# 2  2.370000  3.677500  4.052500  ...  3.331667  1.488333     1.422500
# 3  1.910000  3.797500  4.165000  ...  3.162500  1.495000     1.265000
# 4  1.130000  3.533333  4.026667  ...  3.356667  1.180000     1.640000
#
#    t_4C1a2l_rev  t_4A4a5_rev  t_4A4a8_rev  t_4A1b2_rev  t_4A3a2_rev  \
# 0      1.193333     3.215000     2.353333     3.186667     4.023333
# 1      1.130000     3.795000     2.950000     3.630000     4.520000
# 2      1.225833     3.276667     2.597500     2.725833     3.767500
# 3      1.090000     3.427500     2.550000     3.100000     4.015000
# 4      1.110000     3.770000     3.570000     4.243333     4.686667
#
#    t_4A3b4_rev  t_4A3b5_rev
# 0     4.365000     4.381667
# 1     4.835000     4.805000
# 2     3.953333     4.114167
# 3     4.297500     4.432500
# 4     4.990000     4.883333
#
# [5 rows x 25 columns]

# %%
# Check for missing values
df.isnull().sum()

# Drop rows with missing values (optional)
df.dropna(inplace=True)

# Remove duplicates
df.drop_duplicates(inplace=True)

# Check data types
df.dtypes
# Out:
# isco08            int64
# t_1A1f1         float64
# t_1A2a2         float64
# t_2B1a          float64
# t_4A2a4         float64
# t_4A2b2         float64
# t_4A3a3         float64
# t_4A3a4         float64
# t_4A4a1         float64
# t_4A4a4         float64
# t_4A4b4         float64
# t_4A4b5         float64
# t_4C2d1g        float64
# t_4C2d1i        float64
# t_4C3b4         float64
# t_4C3b7         float64
# t_4C3d3         float64
# t_4C3b8_rev     float64
# t_4C1a2l_rev    float64
# t_4A4a5_rev     float64
# t_4A4a8_rev     float64
# t_4A1b2_rev     float64
# t_4A3a2_rev     float64
# t_4A3b4_rev     float64
# t_4A3b5_rev     float64
# dtype: object

# %%
# Histogram of a column (replace with your column name)
sns.histplot(df['isco08'])  # change to actual column
plt.title('Distribution of Column')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.to_csv('cleaned_dataset.csv', index=False)
